# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Problem1.csv")
df
# Out:
#    State/Union Territory  2004-05  2005-06  2006-07  2007-08  2008-09  \
# 0         Andhra Pradesh     9601    11704    11872    13324    14241
# 1      Arunachal Pradesh      135    146.2    146.2    158.1    163.9
# 2                  Assam   3470.7   3552.5     2916     3319   4008.5
# 3                  Bihar   2472.2   3495.5   4989.3   4418.1   5590.3
# 4           Chhattisgarh   4383.3   5011.6   5041.4   5426.6   4391.8
# 5           NCT of Delhi     14.3       24     31.1     31.4     31.4
# 6                    Goa    145.2    147.3    130.3    121.6    123.3
# 7                Gujarat   1238.2     1298     1390     1474     1303
# 8                Haryana     3023     3210     3371     3613     3298
# 9       Himachal Pradesh      122    112.1    123.5    121.5    118.3
# 10       Jammu & Kashmir    492.2    556.8      554    561.3    563.1
# 11             Jharkhand     1677     1558   2967.8   3336.4   3420.2
# ...

# %%
df_transposed = df.copy().transpose()
df_transposed
# Out:
#                                    0                  1       2       3   \
# State/Union Territory  Andhra Pradesh  Arunachal Pradesh   Assam   Bihar
# 2004-05                          9601                135  3470.7  2472.2
# 2005-06                         11704              146.2  3552.5  3495.5
# 2006-07                         11872              146.2    2916  4989.3
# 2007-08                         13324              158.1    3319  4418.1
# 2008-09                         14241              163.9  4008.5  5590.3
# 2009-10                         10538              215.8  4335.9  3599.3
# 2010-11                        7882.4              234.0  4736.6  3102.1
# 2011-12                        7746.2              255.0  4516.3  7162.6
# 2012-13                        6862.4              263.0  5128.5  7529.3
# 2013-14                        6969.7              276.2  4927.1  5505.8
# 2014-15                        7233.9              285.0  5222.7  6356.7
# ...

# %%
df_transposed.to_csv('transposed_df.csv', header=False, index=True)

# %%
new_df = pd.read_csv("transposed_df.csv")
new_df
# Out:
#    State/Union Territory  Andhra Pradesh Arunachal Pradesh   Assam   Bihar  \
# 0                2004-05          9601.0               135  3470.7  2472.2
# 1                2005-06         11704.0             146.2  3552.5  3495.5
# 2                2006-07         11872.0             146.2  2916.0  4989.3
# 3                2007-08         13324.0             158.1  3319.0  4418.1
# 4                2008-09         14241.0             163.9  4008.5  5590.3
# 5                2009-10         10538.0             215.8  4335.9  3599.3
# 6                2010-11          7882.4             234.0  4736.6  3102.1
# 7                2011-12          7746.2             255.0  4516.3  7162.6
# 8                2012-13          6862.4             263.0  5128.5  7529.3
# 9                2013-14          6969.7             276.2  4927.1  5505.8
# 10               2014-15          7233.9             285.0  5222.7  6356.7
# ...

# %%
new_df = new_df.rename(columns={"State/Union Territory":"Year"})
new_df.head()
# Out:
#       Year  Andhra Pradesh Arunachal Pradesh   Assam   Bihar  Chhattisgarh  \
# 0  2004-05          9601.0               135  3470.7  2472.2        4383.3
# 1  2005-06         11704.0             146.2  3552.5  3495.5        5011.6
# 2  2006-07         11872.0             146.2  2916.0  4989.3        5041.4
# 3  2007-08         13324.0             158.1  3319.0  4418.1        5426.6
# 4  2008-09         14241.0             163.9  4008.5  5590.3        4391.8
#
#   NCT of Delhi    Goa  Gujarat  Haryana  ...   Punjab Rajasthan  Sikkim  \
# 0         14.3  145.2   1238.2   3023.0  ...  10437.0     150.4    21.6
# 1           24  147.3   1298.0   3210.0  ...  10193.0     153.0    21.5
# 2         31.1  130.3   1390.0   3371.0  ...  10138.0     169.8    21.5
# 3         31.4  121.6   1474.0   3613.0  ...  10489.0     259.6    22.9
# 4         31.4  123.3   1303.0   3298.0  ...  11000.0     241.1    21.7
#
#    Tamil Nadu  Telangana  Tripura  Uttar Pradesh Uttarakhand West Bengal  \
# ...

# %%
yr = [i for i in range(2004,2023)]
new_df["Year"] = yr
new_df
# Out:
#     Year  Andhra Pradesh Arunachal Pradesh   Assam   Bihar  Chhattisgarh  \
# 0   2004          9601.0               135  3470.7  2472.2        4383.3
# 1   2005         11704.0             146.2  3552.5  3495.5        5011.6
# 2   2006         11872.0             146.2  2916.0  4989.3        5041.4
# 3   2007         13324.0             158.1  3319.0  4418.1        5426.6
# 4   2008         14241.0             163.9  4008.5  5590.3        4391.8
# 5   2009         10538.0             215.8  4335.9  3599.3        4110.4
# 6   2010          7882.4             234.0  4736.6  3102.1        6159.0
# 7   2011          7746.2             255.0  4516.3  7162.6        6028.4
# 8   2012          6862.4             263.0  5128.5  7529.3        6608.8
# 9   2013          6969.7             276.2  4927.1  5505.8        6716.4
# 10  2014          7233.9             285.0  5222.7  6356.7        6322.1
# 11  2015          7488.7             204.0  5125.1  6802.2        5789.4
# ...

# %%
new_df.to_csv("processed_ds1.csv", index = False)

# %% [markdown]
# *   Handle missing or incorrect values. For example, replacing periods (".") with NaN (Not a Number) to accurately reflect missing data.

# %%
new_df.replace('-', np.nan, inplace=True)

new_df = new_df.apply(pd.to_numeric, errors='coerce')

# %%
new_df
# Out:
#     Year  Andhra Pradesh  Arunachal Pradesh   Assam   Bihar  Chhattisgarh  \
# 0   2004          9601.0              135.0  3470.7  2472.2        4383.3
# 1   2005         11704.0              146.2  3552.5  3495.5        5011.6
# 2   2006         11872.0              146.2  2916.0  4989.3        5041.4
# 3   2007         13324.0              158.1  3319.0  4418.1        5426.6
# 4   2008         14241.0              163.9  4008.5  5590.3        4391.8
# 5   2009         10538.0              215.8  4335.9  3599.3        4110.4
# 6   2010          7882.4              234.0  4736.6  3102.1        6159.0
# 7   2011          7746.2              255.0  4516.3  7162.6        6028.4
# 8   2012          6862.4              263.0  5128.5  7529.3        6608.8
# 9   2013          6969.7              276.2  4927.1  5505.8        6716.4
# 10  2014          7233.9              285.0  5222.7  6356.7        6322.1
# 11  2015          7488.7              204.0  5125.1  6802.2        5789.4
# ...
